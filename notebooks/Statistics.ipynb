# %%
import pandas as pd

baseline_results = pd.read_csv("results/baseline/results-baseline-06-09.csv")
baseline_results
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 0    0   171.12    250.28        1            0        0        0
# 1    1   141.93    213.29        1            0        0        0
# 2    2   443.80    621.72        0            0        0        1
# 3    3   156.33    239.31        1            0        0        0
# 4    4   681.48    900.11        0            0        1        0
# ..  ..      ...       ...      ...          ...      ...      ...
# 75  76   594.00    715.84        0            0        0        1
# 76  77   674.43    810.96        0            0        0        1
# 77  78   571.80    686.94        0            0        0        1
# 78  79   527.82    621.72        0            0        0        1
# 79  80   399.97    477.61        0            0        0        1
#
# [80 rows x 7 columns]

# %%
planned_results = pd.read_csv("results/planned/results-planned-06-09.csv")
planned_results
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 0    0   217.03    311.41        0            0        0        1
# 1    1   366.63    505.55        0            0        0        1
# 2    2   262.18    372.47        0            0        0        1
# 3    3   202.65    284.36        0            0        0        1
# 4    4   198.90    282.34        0            0        0        1
# ..  ..      ...       ...      ...          ...      ...      ...
# 75  76   357.57    442.51        0            0        0        1
# 76  77   519.48    629.80        0            1        0        0
# 77  78   804.85    900.16        0            0        1        0
# 78  79   475.02    591.70        1            0        0        0
# 79  80   417.65    544.66        0            0        0        1
#
# [80 rows x 7 columns]

# %% [markdown]
# # Baseline Results

# %%
baseline_success = baseline_results[baseline_results["Success"] == 1]
baseline_success
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 2    2   443.80    621.72        0            0        0        1
# 5    5   304.17    424.09        0            0        0        1
# 7    7   393.40    545.65        0            0        0        1
# 9    9   245.45    346.46        0            0        0        1
# 13  14   665.70    816.98        0            0        0        1
# 15  16   396.55    506.62        0            0        0        1
# 16  17   319.88    412.49        0            0        0        1
# 18  19   413.83    530.68        0            0        0        1
# 19  20   583.53    732.90        0            0        0        1
# 21  22   586.77    742.87        0            0        0        1
# 22  23   370.25    486.56        0            0        0        1
# 24  25   416.60    526.67        0            0        0        1
# 26  27   437.48    553.72        0            0        0        1
# ...

# %%
baseline_fail = baseline_results[baseline_results["Failure"] == 1]
baseline_fail
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 0    0   171.12    250.28        1            0        0        0
# 1    1   141.93    213.29        1            0        0        0
# 3    3   156.33    239.31        1            0        0        0
# 8    8   171.23    245.34        1            0        0        0
# 11  12   188.08    260.33        1            0        0        0
# 12  13   129.00    183.26        1            0        0        0
# 14  15   203.78    275.36        1            0        0        0
# 17  18   173.70    237.34        1            0        0        0
# 20  21   157.62    214.25        1            0        0        0
# 29  30   114.42    152.19        1            0        0        0
# 31  32   123.35    161.22        1            0        0        0
# 32  33   205.83    266.30        1            0        0        0
# 54  55   474.47    565.64        1            0        0        0
# ...

# %%
base_sim_mean = baseline_success["Sim TTC"].mean()
base_sim_mean
# Out:
# 419.005283018868

# %%
base_sim_std = baseline_success["Sim TTC"].std()
base_sim_std
# Out:
# 141.23263760689002

# %%
base_wall_mean = baseline_success["Wall TTC"].mean()
base_wall_mean
# Out:
# 519.7177358490566

# %%
base_wall_std = baseline_success["Wall TTC"].std()
base_wall_std
# Out:
# 168.52499686352752

# %%
basefail_sim_mean = baseline_fail["Sim TTC"].mean()
basefail_sim_mean
# Out:
# 224.79133333333328

# %%
basefail_sim_std = baseline_fail["Sim TTC"].std()
basefail_sim_std
# Out:
# 135.501301304593

# %%
basefail_wall_mean = baseline_fail["Wall TTC"].mean()
basefail_wall_mean
# Out:
# 295.50333333333333

# %%
basefail_wall_std = baseline_fail["Wall TTC"].std()
basefail_wall_std
# Out:
# 152.63293244469446

# %% [markdown]
# # Planner Results

# %%
planned_success = planned_results[planned_results["Success"] == 1]
planned_success
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 0    0   217.03    311.41        0            0        0        1
# 1    1   366.63    505.55        0            0        0        1
# 2    2   262.18    372.47        0            0        0        1
# 3    3   202.65    284.36        0            0        0        1
# 4    4   198.90    282.34        0            0        0        1
# ..  ..      ...       ...      ...          ...      ...      ...
# 72  73   341.38    426.57        0            0        0        1
# 73  74   294.60    368.44        0            0        0        1
# 74  75   476.80    578.71        0            0        0        1
# 75  76   357.57    442.51        0            0        0        1
# 79  80   417.65    544.66        0            0        0        1
#
# [71 rows x 7 columns]

# %%
planned_fail = planned_results[planned_results["Failure"] == 1]
planned_fail
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 42  43   263.68    345.39        1            0        0        0
# 48  49   443.82    557.70        1            0        0        0
# 78  79   475.02    591.70        1            0        0        0

# %%
planned_lowbattery = planned_results[planned_results["Low Battery"] == 1]
planned_lowbattery
# Out:
#     id  Sim TTC  Wall TTC  Failure  Low Battery  Tiemout  Success
# 22  23   518.98    665.76        0            1        0        0
# 76  77   519.48    629.80        0            1        0        0

# %%
success_sim_mean = planned_success["Sim TTC"].mean()
success_sim_mean
# Out:
# 329.9554929577465

# %%
success_sim_std = planned_success["Sim TTC"].std()
success_sim_std
# Out:
# 99.31781702895195

# %%
success_wall_mean = planned_success["Wall TTC"].mean()
success_wall_mean
# Out:
# 425.4538028169013

# %%
success_wall_std = planned_success["Wall TTC"].std()
success_wall_std
# Out:
# 122.31139045621217

# %%
fail_sim_mean = planned_fail["Sim TTC"].mean()
fail_sim_mean
# Out:
# 394.17333333333335

# %%
fail_sim_std = planned_fail["Sim TTC"].std()
fail_sim_std
# Out:
# 114.08217447670486

# %%
fail_wall_mean = planned_fail["Wall TTC"].mean()
fail_wall_mean
# Out:
# 498.2633333333333

# %%
fail_wall_std = planned_fail["Wall TTC"].std()
fail_wall_std
# Out:
# 133.47918202226646

# %%
lowbattery_sim_mean = planned_lowbattery["Sim TTC"].mean()
lowbattery_sim_mean
# Out:
# 519.23

# %%
lowbattery_sim_std = planned_lowbattery["Sim TTC"].std()
lowbattery_sim_std
# Out:
# 0.3535533905932738

# %%
lowbattery_wall_mean = planned_lowbattery["Wall TTC"].mean()
lowbattery_wall_mean
# Out:
# 647.78

# %%
lowbattery_wall_std = planned_lowbattery["Wall TTC"].std()
lowbattery_wall_std
# Out:
# 25.427559851468274

# %% [markdown]
# # Table of results

# %%
dic = {'Baseline Success': [base_sim_mean, base_sim_std, base_wall_mean, base_wall_std],
       'Baseline Failure': [basefail_sim_mean, basefail_sim_std, basefail_wall_mean, basefail_wall_std],
       'Planner Success': [success_sim_mean, success_sim_std, success_wall_mean, success_wall_std],
       'Planner Failure': [fail_sim_mean, fail_sim_std, fail_wall_mean, fail_wall_std],
       'Planner Low Battery': [lowbattery_sim_mean, lowbattery_sim_std, lowbattery_wall_mean, lowbattery_wall_std]}
df = pd.DataFrame(dic, index=['Sim TTC Mean', 'Sim TTC STD', 'Wall TTC Mean', 'Wall TTC STD'])
df
# Out:
#                Baseline Success  Baseline Failure  Planner Success  \
# Sim TTC Mean         419.005283        224.791333       329.955493
# Sim TTC STD          141.232638        135.501301        99.317817
# Wall TTC Mean        519.717736        295.503333       425.453803
# Wall TTC STD         168.524997        152.632932       122.311390
#
#                Planner Failure  Planner Low Battery
# Sim TTC Mean        394.173333           519.230000
# Sim TTC STD         114.082174             0.353553
# Wall TTC Mean       498.263333           647.780000
# Wall TTC STD        133.479182            25.427560

# %%
df.to_csv('results_comparison.csv')

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Metric1
# Planner Success as compared to Baseline Successes

# %%
metric1 = len(planned_success)/len(baseline_success) * 100
metric1
# Out:
# 133.96226415094338

# %% [markdown]
# ## Metric2
# Planner TTC as compared to Baseline TTC

# %%
metric2 = success_sim_mean/base_sim_mean * 100
metric2
# Out:
# 78.74733477832748

# %% [markdown]
# # Metric3
